# %%
import pandas as pd

# %% [markdown]
# ## Drop

# %%
data = {'name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'year': [2012, 2012, 2013, 2014, 2014], 
        'reports': [4, 24, 31, 2, 3]}
df = pd.DataFrame(data, index = ['Cochice', 'Pima', 'Santa Cruz', 'Maricopa', 'Yuma'])
df
# Out:
#              name  reports  year
# Cochice     Jason        4  2012
# Pima        Molly       24  2012
# Santa Cruz   Tina       31  2013
# Maricopa     Jake        2  2014
# Yuma          Amy        3  2014

# %% [markdown]
# # Drop by label and by index in rows

# %%
df.drop(['Cochice', 'Pima'])
# Out:
#             name  reports  year
# Santa Cruz  Tina       31  2013
# Maricopa    Jake        2  2014
# Yuma         Amy        3  2014

# %%
df.drop(df.index[0])
# Out:
#              name  reports  year
# Pima        Molly       24  2012
# Santa Cruz   Tina       31  2013
# Maricopa     Jake        2  2014
# Yuma          Amy        3  2014

# %% [markdown]
# # Drop by label in column

# %%
df.drop('reports', axis=1)
# Out:
#              name  year
# Cochice     Jason  2012
# Pima        Molly  2012
# Santa Cruz   Tina  2013
# Maricopa     Jake  2014
# Yuma          Amy  2014

# %% [markdown]
# # Bolean Masking

# %%
df = pd.read_csv('olympics.csv', index_col = 0, skiprows=1)

# %%
for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold' + col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver' + col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze' + col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#' + col[1:]}, inplace=True) 

df.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
# ...

# %%
df['Gold'] > 0
# Out:
# Afghanistan (AFG)                               False
# Algeria (ALG)                                    True
# Argentina (ARG)                                  True
# Armenia (ARM)                                    True
# Australasia (ANZ) [ANZ]                          True
# Australia (AUS) [AUS] [Z]                        True
# Austria (AUT)                                    True
# Azerbaijan (AZE)                                 True
# Bahamas (BAH)                                    True
# Bahrain (BRN)                                   False
# Barbados (BAR) [BAR]                            False
# Belarus (BLR)                                    True
# Belgium (BEL)                                    True
# Bermuda (BER)                                   False
# Bohemia (BOH) [BOH] [Z]                         False
# Botswana (BOT)                                  False
# Brazil (BRA)                                     True
# ...

# %%
df[df['Gold'] > 0]
# Out:
#                                      # Summer  Gold  Silver  Bronze  Total  \
# Algeria (ALG)                              12     5       2       8     15
# Argentina (ARG)                            23    18      24      28     70
# Armenia (ARM)                               5     1       2       9     12
# Australasia (ANZ) [ANZ]                     2     3       4       5     12
# Australia (AUS) [AUS] [Z]                  25   139     152     177    468
# Austria (AUT)                              26    18      33      35     86
# Azerbaijan (AZE)                            5     6       5      15     26
# Bahamas (BAH)                              15     5       2       5     12
# Belarus (BLR)                               5    12      24      39     75
# Belgium (BEL)                              25    37      52      53    142
# Brazil (BRA)                               21    23      30      55    108
# ...

# %%
df1=df.where(df['Gold'] > 0)
df1
# Out:
#                                               # Summer    Gold  Silver  \
# Afghanistan (AFG)                                  NaN     NaN     NaN
# Algeria (ALG)                                     12.0     5.0     2.0
# Argentina (ARG)                                   23.0    18.0    24.0
# Armenia (ARM)                                      5.0     1.0     2.0
# Australasia (ANZ) [ANZ]                            2.0     3.0     4.0
# Australia (AUS) [AUS] [Z]                         25.0   139.0   152.0
# Austria (AUT)                                     26.0    18.0    33.0
# Azerbaijan (AZE)                                   5.0     6.0     5.0
# Bahamas (BAH)                                     15.0     5.0     2.0
# Bahrain (BRN)                                      NaN     NaN     NaN
# Barbados (BAR) [BAR]                               NaN     NaN     NaN
# Belarus (BLR)                                      5.0    12.0    24.0
# ...

# %%
df.index
# Out:
# Index(['Afghanistan (AFG)', 'Algeria (ALG)', 'Argentina (ARG)',
#        'Armenia (ARM)', 'Australasia (ANZ) [ANZ]', 'Australia (AUS) [AUS] [Z]',
#        'Austria (AUT)', 'Azerbaijan (AZE)', 'Bahamas (BAH)', 'Bahrain (BRN)',
#        ...
#        'Uzbekistan (UZB)', 'Venezuela (VEN)', 'Vietnam (VIE)',
#        'Virgin Islands (ISV)', 'Yugoslavia (YUG) [YUG]',
#        'Independent Olympic Participants (IOP) [IOP]', 'Zambia (ZAM) [ZAM]',
#        'Zimbabwe (ZIM) [ZIM]', 'Mixed team (ZZX) [ZZX]', 'Totals'],
#       dtype='object', length=147)

# %%
df.columns
# Out:
# Index(['# Summer', 'Gold', 'Silver', 'Bronze', 'Total', '# Winter', 'Gold.1',
#        'Silver.1', 'Bronze.1', 'Total.1', '# Games', 'Gold.2', 'Silver.2',
#        'Bronze.2', 'Combined total'],
#       dtype='object')

# %%
df.index[1]
# Out:
# 'Algeria\xa0(ALG)'

# %%
df.head(3)
df['Country']=df.index
df
# Out:
#                                               # Summer  Gold  Silver  Bronze  \
# Afghanistan (AFG)                                   13     0       0       2
# Algeria (ALG)                                       12     5       2       8
# Argentina (ARG)                                     23    18      24      28
# Armenia (ARM)                                        5     1       2       9
# Australasia (ANZ) [ANZ]                              2     3       4       5
# Australia (AUS) [AUS] [Z]                           25   139     152     177
# Austria (AUT)                                       26    18      33      35
# Azerbaijan (AZE)                                     5     6       5      15
# Bahamas (BAH)                                       15     5       2       5
# Bahrain (BRN)                                        8     0       0       1
# Barbados (BAR) [BAR]                                11     0       0       1
# ...

# %%
df1=df.reset_index()
df1
df1.iloc[[2,3,6]]
# Out:
#              index  # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# 2  Argentina (ARG)        23    18      24      28     70        18       0
# 3    Armenia (ARM)         5     1       2       9     12         6       0
# 6    Austria (AUT)        26    18      33      35     86        22      59
#
#    Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# 2         0         0        0       41      18        24        28
# 3         0         0        0       11       1         2         9
# 6        78        81      218       48      77       111       116
#
#    Combined total          Country
# 2              70  Argentina (ARG)
# 3              12    Armenia (ARM)
# 6             304    Austria (AUT)

# %%
df1.head(3)
# Out:
#                index  # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# 0  Afghanistan (AFG)        13     0       0       2      2         0       0
# 1      Algeria (ALG)        12     5       2       8     15         3       0
# 2    Argentina (ARG)        23    18      24      28     70        18       0
#
#    Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# 0         0         0        0       13       0         0         2
# 1         0         0        0       15       5         2         8
# 2         0         0        0       41      18        24        28
#
#    Combined total
# 0               2
# 1              15
# 2              70

# %%
# As you can see, you can not use index column in above. So, the best way is to create a column 
# name with the approperiate name to store index and then use it.
df.set_index('index')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\mohammad\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'index'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df3=df.set_index('Country')
df3
# Out:
#                                               # Summer  Gold  Silver  Bronze  \
# Country
# Afghanistan (AFG)                                   13     0       0       2
# Algeria (ALG)                                       12     5       2       8
# Argentina (ARG)                                     23    18      24      28
# Armenia (ARM)                                        5     1       2       9
# Australasia (ANZ) [ANZ]                              2     3       4       5
# Australia (AUS) [AUS] [Z]                           25   139     152     177
# Austria (AUT)                                       26    18      33      35
# Azerbaijan (AZE)                                     5     6       5      15
# Bahamas (BAH)                                       15     5       2       5
# Bahrain (BRN)                                        8     0       0       1
# Barbados (BAR) [BAR]                                11     0       0       1
# ...

# %%
df3.loc['Algeria\xa0(ALG)']
# Out:
# # Summer          12
# Gold               5
# Silver             2
# Bronze             8
# Total             15
# # Winter           3
# Gold.1             0
# Silver.1           0
# Bronze.1           0
# Total.1            0
# # Games           15
# Gold.2             5
# Silver.2           2
# Bronze.2           8
# Combined total    15
# Name: Algeria (ALG), dtype: int64
